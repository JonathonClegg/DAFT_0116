# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig1 = plt.figure(figsize=(6,6)) #Prepare canvas with dimensions, width and height
plt.plot(x,y, color='r', label='red line') #colour can take hex value or letter r, g for example
plt.plot(x,z, color='g', label='green line') #you can plot second line by duplicating the line.
plt.title("Challenge 1: Plot (x, y) and (x, z)")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend(loc="upper left") #To call legened your plots need labels. You can chnage the location also

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, ax = plt.subplots(1,2,figsize= (12,10))
ax[0].plot(x,y, color='r', label='red line')
ax[1].plot(x,z, color='g', label='green line')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig, ax = plt.subplots(1,2,figsize= (8,6))
ax[0].plot(x,y, color='r', label='red line')
ax[1].plot(x,z, color='g', label='green line')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

fig1 = plt.figure()

ax0, ax1 = fig1.subplots(1, 2)

ax0.plot(x,x**2, color='r')
ax0.set_xscale('linear')

ax1.plot(x,np.exp(x), color='g')
ax1.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig1 = plt.figure()
ax0, ax1 = fig1.subplots(1, 2)

ax0.plot(x,x**2, color='r', label='red line')
ax0.set_xscale('linear')

ax1.plot(x,np.exp(x), color='g', label='green line')
ax1.set_yscale('log')

ax0.legend(loc='best', fontsize='small')
ax1.legend(loc='best', fontsize='small')

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('/Users/jon/Documents/IRONHACK/DAFT_0116/module_2/Lab_1_Matplotlib-and-Seaborn/Fitbit2.csv')
fitbit.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
median_steps_month = fitbit.groupby(['Months'])['Steps'].median().reset_index().round(0)
median_steps_month

plt.figure(figsize=(20,8))
plt.title('MEDIAN STEPS BY MONTH', size='25', fontweight='bold')
sns.barplot(x = fitbit['Months'], y = fitbit['Steps'])
fig.savefig("MEDIAN STEPS BY MONTH.jpg")

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

median_steps_work_weekend = fitbit.groupby(['Work_or_Weekend'])['Steps'].median().reset_index().round(0)
median_steps_work_weekend

plt.figure(figsize=(10,8))
plt.title('MEDIAN STEPS ON WORK DAYS AND WEEKDAYS', size='25', fontweight='bold')
sns.barplot(x = fitbit['Work_or_Weekend'], y = fitbit['Steps'])
fig.savefig("MEDIAN STEPS ON WORK DAYS AND WEEKDAYS.jpg")
# Out:
# <AxesSubplot:title={'center':'MEDIAN STEPS ON WORK DAYS AND WEEKDAYS'}, xlabel='Work_or_Weekend', ylabel='Steps'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
List = [["Minutes Lightly Active"],["Minutes Very Active"], ["Minutes Sedentary"]]
for [i] in List:
    sns.scatterplot(x=fitbit[i],y=fitbit["Steps"])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv('/Users/jon/Documents/IRONHACK/DAFT_0116/module_2/Lab_1_Matplotlib-and-Seaborn/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes('number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes('object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

#plt.figure(figsize=(12,6))
plt.style.use('classic')
plt.style.use('Solarize_Light2')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

sns.displot(titanic.Age)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
plt.subplot(1,3,1)
plt.hist(titanic['Age'], 
 = 10)

plt.subplot(1,3,2)
plt.hist(titanic['Age'], bins = 20)

plt.subplot(1,3,3)
plt.hist(titanic['Age'], bins = 50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
There is more precision in the distribution.
"""
# Out:
# '\nThere is more variation in the distribution.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic.Age)
# Out:
# /Users/jon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender = titanic['Gender'].value_counts().sort_index()
plt.bar(gender.index, gender, color=('red','green'))
plt.title('Titanic Gender Composition', fontweight='bold')
plt.xticks(ticks=[0,1],labels=["Female","Male"])
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Method 2 - seaborn
# your code here
ax = sns.countplot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
Pclass = titanic['Pclass'].value_counts().sort_index()
plt.bar(Pclass.index, Pclass, color=('red','green','blue'))
plt.title('Titanic Passenger Class Distribution', fontweight='bold')
plt.xticks(ticks=[1,2,3],labels=["First","Second", "Third"])
plt.ylabel("Count")

#could also use countplot = sns.countplot(x="Pclass", data=titanic)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# your code here
sns.boxplot(x="Age",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Age has a large variance with a lot of outliers.
It also has a relatively small IQR meaning the majority of people are aged between 22 and 38 approximately.
"""
# Out:
# '\nAge has a large variance with a lot of outliers.\nIt also has a relatively small IQR meaning the majority of people are aged between 22 and 38 approximately.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.set(style="darkgrid")
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
# assigning a graph to each ax
sns.boxplot(data=titanic,x="Age", ax=ax_box)
sns.histplot(titanic, x="Age", ax=ax_hist)
f.tight_layout()
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# [Text(0.5, 374.0808080808081, '')]

# %%
# your code here
graph_age = sns.distplot(titanic.Age)
graph_age.axvline(titanic["Age"].mean(), color='r', lw=2)
graph_age.axvline(titanic["Age"].median(), color='orange', ls='--', lw=2)
# Out:
# /Users/jon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.violinplot(titanic.Age)
# Out:
# /Users/jon/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
You can see that age is normally distributed, if not slightly left skewed.
You can also see how many people fall into which age bracket

"""
# Out:
# '\nYou can see that age is normally distributed, if not slightly left skewed.\nYou can also see how many people fall into which age bracket\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
x = titanic["Age"]
y = titanic["Fare"]
plt.figure()
plt.scatter(x,y)
plt.title("Relationship between `Fare` and `Age`")
plt.legend()
plt.xlabel("Age")
plt.ylabel("Fare")
print("Correlation between Fare and Age:", x.corr(y))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Correlation between Fare and Age: 0.17135508596244758

# %%
# Method 2 - seaborn
# your code here

print("Correlation between Fare and Age:", x.corr(y))
sns.scatterplot(x=titanic.Age,y=titanic.Fare)
# Out:
# Correlation between Fare and Age: 0.17135508596244758
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.regplot(x=titanic.Age,y=titanic.Fare)
#regplot adds the regression line
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Passenger class & Fare (-0.56)
Age & Passeger class (-0.43)
Passenger Class & Survived (-0.34)

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
fg7 = sns.catplot(x='Pclass', y = 'Age', data = titanic, kind="box", margin_titles = True)
fg7.fig.suptitle('Passenger class distribution by age', size='20', fontweight='bold', y = 1.05)
fg7.set_xticklabels(['First', 'Second', 'Third'])
fg7.set_ylabels('Age')
fg7.set_xlabels('')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
fg8 = sns.catplot(x='Gender', y = 'Age', data = titanic, kind="box", margin_titles = True)
fg8.fig.suptitle('Age distribution by Gender', size='20', fontweight='bold', y = 1.05)
fg8.set_xticklabels(['Male', 'Female'])
fg8.set_ylabels('Age')
fg8.set_xlabels('')

# %%
sns.displot(titanic, x="Age", hue="Gender")
